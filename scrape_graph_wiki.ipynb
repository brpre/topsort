# %% [markdown]
# ## Web Scraping Example: Optimized Learning with Knowledge Graphs
# - finds and orders prerequisite knowledge for a given source
# - Collects linked references from given Wiki page with web scraping

# %%
# get libraries for html get request, bs4 for parsing web to json, 
# pandas for df's, and re for regexes (see below for more regex details)
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
# choose any wiki page as the start node: let's use a relevant topic of the sort of thing 
# we're trying to emulate, get data from that URL
gkg_page = requests.get('https://en.wikipedia.org/wiki/Google_Knowledge_Graph')
# create a soup object with the html parser
gkg_soup = BeautifulSoup(gkg_page.content, 'html.parser')

# %% [markdown]
# ![after inspecting a wiki page, I found that the tag mw-content-text is the main text area w/ links](wiki_main_scrape.png)

# %%
# from the soup, get the first div from the main body with id 'bodyContent'
# from bodyContent, get nested div with id 'mw-content-text'
gkg_body = gkg_soup.find('div', {'id': 'bodyContent'}).find('div', {'id': 'mw-content-text'})
# IMPORTANT FOR TASK: find all 'a' tags from this page, these are our links
gkg_fa = gkg_body.find_all('a', href=True)
# use a list comprehension (fancy one-liner loop syntax) to get the link (the 'href') from each a tag
gkg_links = [a['href'] for a in gkg_fa]
gkg_links[:15]
# Out:
# ['/wiki/Knowledge_graph',
#  '/wiki/File:Google_Knowledge_Panel.png',
#  '/wiki/File:Google_Knowledge_Panel.png',
#  '/wiki/Thomas_Jefferson',
#  '/wiki/Google_Search',
#  '/wiki/Knowledge_base',
#  '/wiki/Google',
#  '/wiki/Google_Search',
#  '/wiki/Infobox',
#  '/wiki/Search_engine_results_page',
#  '#cite_note-:0-1',
#  '#cite_note-2',
#  '#cite_note-3',
#  '#cite_note-4',
#  '#cite_note-5']

# %%
# note that our links has a bunch of things that we don't want, like external links and others
# filter out the links that don't go to other wiki pages, match regex for wiki endpoint 
gkg_labels_all = list(filter(re.compile('^/wiki/').match, gkg_links))
# exclude files, specials, templates, etc Thing:resource
gkg_labels = list(set(gkg_labels_all) - set(filter(re.compile('.*:.*').match, gkg_labels_all)))
gkg_labels
# Out:
# ['/wiki/Google_Get_Your_Business_Online',
#  '/wiki/WebM',
#  '/wiki/PageRank_algorithm_in_biochemistry',
#  '/wiki/Wolfram_Alpha',
#  '/wiki/Google_Web_Designer',
#  '/wiki/Android_Beam',
#  '/wiki/Google_The_Thinking_Factory',
#  '/wiki/Area_120',
#  '/wiki/Googlefight',
#  '/wiki/Google%2B',
#  '/wiki/Waze',
#  '/wiki/Pixel_3',
#  '/wiki/Google_Store',
#  '/wiki/AV1',
#  '/wiki/Axel_Springer_SE',
#  '/wiki/Google_Analytics',
#  '/wiki/Urchin_(software)',
#  '/wiki/The_Verge',
#  '/wiki/Tensor_Processing_Unit',
#  '/wiki/Computability',
#  '/wiki/Google_Catalogs',
#  '/wiki/Kaggle',
#  '/wiki/Android_Studio',
#  '/wiki/Google_WiFi',
#  '/wiki/Google_Helpouts',
#  '/wiki/Nexus_4',
#  '/wiki/Google_Search_Appliance',
#  '/wiki/Business_Insider',
#  '/wiki/DeGoogle',
#  '/wiki/AngularJS',
#  '/wiki/Google_Brain',
#  '/wiki/Google_Developer_Day',
#  '/wiki/Google_Chart_API',
#  '/wiki/GYP_(software)',
#  '/wiki/Neotonic_Software',
#  '/wiki/Google_Fit',
#  '/wiki/Pixel_4',
#  '/wiki/Where_on_Google_Earth_is_Carmen_Sandiego%3F',
#  '/wiki/Google_Drawings',
#  '/wiki/Google_Web_Light',
#  '/wiki/Dart_(programming_language)',
#  '/wiki/Google_Volume_One',
#  '/wiki/Google_Data_Studio',
#  '/wiki/PageRank',
#  '/wiki/Google_Free_Zone',
#  '/wiki/Fitbit',
#  '/wiki/Google_Data_Liberation_Front',
#  '/wiki/Comparison_of_Material_Design_implementations',
#  '/wiki/YouTube',
#  '/wiki/The_Billion_Dollar_Code',
#  '/wiki/Google_Bookmarks',
#  '/wiki/Snow_Crash',
#  '/wiki/YouTube_Awards',
#  '/wiki/Google_Sites',
#  '/wiki/Gulliver%27s_Travels',
#  '/wiki/American_fuzzy_lop_(fuzzer)',
#  '/wiki/Messages_(Google)',
#  '/wiki/Google_Flights',
#  '/wiki/Google_Attribution',
#  '/wiki/Googlewhack',
#  '/wiki/Socratic_(Google)',
#  '/wiki/Memex',
#  '/wiki/Google_Duo',
#  '/wiki/Quest_Visual',
#  '/wiki/Crowdsource_(app)',
#  '/wiki/Google_Takeout',
#  '/wiki/Gson',
#  '/wiki/Google_Ads',
#  '/wiki/Android_version_history',
#  '/wiki/Semantic_integration',
#  '/wiki/Antikythera_mechanism',
#  '/wiki/Google_Ad_Manager',
#  '/wiki/The_Register',
#  '/wiki/Chrome_Web_Store',
#  '/wiki/Gayglers',
#  '/wiki/Grace_Hopper_(submarine_communications_cable)',
#  '/wiki/Panoramio',
#  '/wiki/Social_impact_of_YouTube',
#  '/wiki/Chronicle_Security',
#  '/wiki/Comparison_of_Google_Pixel_smartphones',
#  '/wiki/SafeSearch',
#  '/wiki/Nest_Wifi',
#  '/wiki/Doodle_Champion_Island_Games',
#  '/wiki/Invite_Media',
#  '/wiki/Google_Blog_Search',
#  '/wiki/Accelerated_Mobile_Pages',
#  '/wiki/Question_answering',
#  '/wiki/Adscape',
#  '/wiki/YouTube_Shorts',
#  '/wiki/Sound_Amplifier',
#  '/wiki/GLinux',
#  '/wiki/Google_Search_Console',
#  '/wiki/Criticism_of_Google',
#  '/wiki/Google_Sheets',
#  '/wiki/Google_Drive',
#  '/wiki/List_of_Google_products',
#  '/wiki/Ram_Shriram',
#  '/wiki/Quick,_Draw!',
#  '/wiki/Google_Expeditions',
#  '/wiki/Nexus_6',
#  '/wiki/AppJet',
#  '/wiki/Google_Test',
#  '/wiki/Search_engine_manipulation_effect',
#  '/wiki/Chromebox',
#  '/wiki/Internet_Speech_Audio_Codec',
#  '/wiki/VP6',
#  '/wiki/Google_Mashup_Editor',
#  '/wiki/Google_Penguin',
#  '/wiki/VirusTotal',
#  '/wiki/Google_Browser_Sync',
#  '/wiki/Pyra_Labs',
#  '/wiki/Google_TV_(service)',
#  '/wiki/Vevo',
#  '/wiki/Global_IP_Solutions',
#  '/wiki/BeatThatQuote.com',
#  '/wiki/Google_Web_Toolkit',
#  '/wiki/Google_Images',
#  '/wiki/Elsagate',
#  '/wiki/The_Internship',
#  '/wiki/2018_Google_data_breach',
#  '/wiki/Google_Dataset_Search',
#  '/wiki/Trendalyzer',
#  '/wiki/Google_Classroom',
#  '/wiki/YouTube_Live',
#  '/wiki/Google_Answers',
#  '/wiki/Crashlytics',
#  '/wiki/Knowledge_extraction',
#  '/wiki/IGoogle',
#  '/wiki/Google_Cloud_Print',
#  '/wiki/G%C3%B6del%27s_incompleteness_theorems',
#  '/wiki/Roboto',
#  '/wiki/Google_APIs',
#  '/wiki/Google_App_Maker',
#  '/wiki/Nexus_5X',
#  '/wiki/Google_Play',
#  '/wiki/Google_and_Wikipedia',
#  '/wiki/Google_Affiliate_Network',
#  '/wiki/Google_Authenticator',
#  '/wiki/Chrome_Remote_Desktop',
#  '/wiki/Dodgeball_(service)',
#  '/wiki/Digital_Unlocked',
#  '/wiki/Google_Code-in',
#  '/wiki/Federated_Learning_of_Cohorts',
#  '/wiki/Green_Throttle_Games',
#  '/wiki/Is_Google_Making_Us_Stupid%3F',
#  '/wiki/The_Washington_Post',
#  '/wiki/YouTube_Space',
#  '/wiki/Google_Fast_Flip',
#  '/wiki/Nexus_6P',
#  '/wiki/Proceratium_google',
#  '/wiki/Betty_White',
#  '/wiki/Google_Buzz',
#  '/wiki/Google_Personalized_Search',
#  '/wiki/Me_at_the_zoo',
#  '/wiki/Formal_system',
#  '/wiki/YouTuber',
#  '/wiki/Watson_(computer)',
#  '/wiki/Files_(Google)',
#  '/wiki/GOOG-411',
#  '/wiki/Google_Directory',
#  '/wiki/Timeline_of_Google_Search',
#  '/wiki/Impermium',
#  '/wiki/List_of_most-downloaded_Google_Play_applications',
#  '/wiki/Mundaneum',
#  '/wiki/Apture',
#  '/wiki/Google_Image_Swirl',
#  '/wiki/Angular_(web_framework)',
#  '/wiki/Rachel_Whetstone',
#  '/wiki/Googleplex',
#  '/wiki/Android_One',
#  '/wiki/Google_Sidewiki',
#  '/wiki/Political_Google_bombs_in_the_2004_U.S._presidential_election',
#  '/wiki/Google_Cardboard',
#  '/wiki/Coverage_of_Google_Street_View',
#  '/wiki/Google_Stadia',
#  '/wiki/Google_Docs_Editors',
#  '/wiki/RankBrain',
#  '/wiki/Speech_Services',
#  '/wiki/YouTube_Creator_Awards',
#  '/wiki/Google_Page_Creator',
#  '/wiki/YouTube_Music',
#  '/wiki/ImageAmerica',
#  '/wiki/2012_Kohistan_video_case',
#  '/wiki/YouTube_headquarters_shooting',
#  '/wiki/Googlebot',
#  '/wiki/Evi_(software)',
#  '/wiki/Commonsense_reasoning',
#  '/wiki/Google_News',
#  '/wiki/Shirley_M._Tilghman',
#  '/wiki/Personal_knowledge_base',
#  '/wiki/Matt_Cutts',
#  '/wiki/Google_Currents',
#  '/wiki/Google_Compute_Engine',
#  '/wiki/Google_Questions_and_Answers',
#  '/wiki/Google_I/O',
#  '/wiki/Android_Things',
#  '/wiki/Google_Checkout',
#  '/wiki/Google_ATAP',
#  '/wiki/Google_Desktop',
#  '/wiki/Nest_Thermostat',
#  '/wiki/Sidewalk_Labs',
#  '/wiki/Google_Camera',
#  '/wiki/Susan_Wojcicki',
#  '/wiki/Google_Play_Newsstand',
#  '/wiki/Smartphone_patent_wars',
#  '/wiki/PlinkArt',
#  '/wiki/I%27m_Feeling_Lucky_(book)',
#  '/wiki/Etherpad',
#  '/wiki/Google_Currents_(2011%E2%80%932013)',
#  '/wiki/Cortana_(virtual_assistant)',
#  '/wiki/Google_Cloud_Messaging',
#  '/wiki/Search_engine_results_page',
#  '/wiki/Automated_reasoning',
#  '/wiki/Privacy_Sandbox',
#  '/wiki/Google_Cloud_Shell',
#  '/wiki/Data_Transfer_Project',
#  '/wiki/Content_ID_(system)',
#  '/wiki/Pixel_5',
#  '/wiki/Google_Labs',
#  '/wiki/Webdriver_Torso',
#  '/wiki/Don%27t_be_evil',
#  '/wiki/Patrick_Pichette',
#  '/wiki/Google_Chrome_Experiments',
#  '/wiki/AdMob',
#  '/wiki/List_of_YouTube_Premium_original_programming',
#  '/wiki/Google_Keep',
#  '/wiki/Booting_process_of_Android_devices',
#  '/wiki/Google_Programmable_Search_Engine',
#  '/wiki/Sycamore_processor',
#  '/wiki/Library_classification',
#  '/wiki/YouTube_API',
#  '/wiki/Schema.org',
#  '/wiki/Google_Guice',
#  '/wiki/Google.by',
#  '/wiki/Google_Talk',
#  '/wiki/Stackdriver',
#  '/wiki/AlphaGo_(film)',
#  '/wiki/Google_Pay_Send',
#  '/wiki/Wear_OS',
#  '/wiki/Google_Now',
#  '/wiki/How_Google_Works',
#  '/wiki/Censorship_by_Google',
#  '/wiki/G-Day',
#  '/wiki/Anvato',
#  '/wiki/Chromecast',
#  '/wiki/Google_Play_Music',
#  '/wiki/Google_Ngram_Viewer',
#  '/wiki/Ontology_(information_science)',
#  '/wiki/Picasa_Web_Albums',
#  '/wiki/Google_Video',
#  '/wiki/Google_Business_Groups',
#  '/wiki/Solve_for_X',
#  '/wiki/Knowledge_engineering',
#  '/wiki/Chromium_(web_browser)',
#  '/wiki/Reply_(Google)',
#  '/wiki/Krishna_Bharat',
#  '/wiki/Living_Stories',
#  '/wiki/Project_Zero',
#  '/wiki/Google_Chrome_Frame',
#  '/wiki/PostRank',
#  '/wiki/Paul_Otellini',
#  '/wiki/Android_Developer_Day',
#  '/wiki/Bitium',
#  '/wiki/ZygoteBody',
#  '/wiki/On2_Technologies',
#  '/wiki/Google.org',
#  '/wiki/Google_Summer_of_Code',
#  '/wiki/Google_Chrome_version_history',
#  '/wiki/ARCore',
#  '/wiki/PaperofRecord.com',
#  '/wiki/The_Google_Story',
#  '/wiki/FairSearch',
#  '/wiki/Firebase_Cloud_Messaging',
#  '/wiki/Product_Sans',
#  '/wiki/Artificial_intelligence_in_fiction#Logic_machines',
#  '/wiki/Google_Fusion_Tables',
#  '/wiki/Chrome_OS',
#  '/wiki/YouTube_(channel)',
#  '/wiki/Ruth_Porat',
#  '/wiki/RechargeIT',
#  '/wiki/Weave_(protocol)',
#  '/wiki/Google_Preferred',
#  '/wiki/Picasa',
#  '/wiki/An_Essay_Towards_a_Real_Character,_and_a_Philosophical_Language',
#  '/wiki/Vox_Media',
#  '/wiki/Jamboard',
#  '/wiki/People_Cards',
#  '/wiki/Google_Question_Hub',
#  '/wiki/TechCrunch',
#  '/wiki/List_of_Google_products#Discontinued_products_and_services',
#  '/wiki/Side_project_time',
#  '/wiki/Google_matrix',
#  '/wiki/Viewdle',
#  '/wiki/Google_bombing',
#  '/wiki/Google_Pigeon',
#  '/wiki/Outline_of_Google',
#  '/wiki/Google_Crisis_Response',
#  '/wiki/BigQuery',
#  '/wiki/Google_URL_Shortener',
#  '/wiki/Street_View_Trusted',
#  '/wiki/Eric_Schmidt',
#  '/wiki/Commonsense_knowledge_(artificial_intelligence)',
#  '/wiki/Semantic_Web',
#  '/wiki/Blogger_(service)',
#  '/wiki/Google_Meet',
#  '/wiki/Gears_(software)',
#  '/wiki/Tilt_Brush',
#  '/wiki/Googleshare',
#  '/wiki/Chromium_OS',
#  '/wiki/WebP',
#  '/wiki/List_of_Android_apps_by_Google',
#  '/wiki/Google_Image_Labeler',
#  '/wiki/Titan_Security_Key',
#  '/wiki/YouTube_copyright_issues',
#  '/wiki/Illegal_flower_tribute',
#  '/wiki/Google_Maps_Road_Trip',
#  '/wiki/Cpplint',
#  '/wiki/LevelDB',
#  '/wiki/Gmail',
#  '/wiki/Google_Hangouts',
#  '/wiki/Google_Calendar',
#  '/wiki/Dewey_Decimal_Classification',
#  '/wiki/Google_Street_View',
#  '/wiki/John_Doerr',
#  '/wiki/Inbox_by_Gmail',
#  '/wiki/Nik_Software',
#  '/wiki/AppSheet',
#  '/wiki/Snapseed',
#  '/wiki/Urs_H%C3%B6lzle',
#  '/wiki/Exposure_Notification',
#  '/wiki/YouTube_Premium',
#  '/wiki/Google_Contacts',
#  '/wiki/Google_Maori',
#  '/wiki/Google_Express',
#  '/wiki/Google_Latitude',
#  '/wiki/Rooting_(Android)',
#  '/wiki/Android_Go',
#  '/wiki/YouTube_Original_Channel_Initiative',
#  '/wiki/Google_data_centers',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Fuchsia_(operating_system)',
#  '/wiki/MapReduce',
#  '/wiki/Pixel_Visual_Core',
#  '/wiki/Nexus_Q',
#  '/wiki/Ramon_Llull',
#  '/wiki/The_Daily_Dot',
#  '/wiki/Google_Maps_pin',
#  '/wiki/A_Logic_Named_Joe',
#  '/wiki/YouTube_Instant',
#  '/wiki/Google_Friend_Connect',
#  '/wiki/Pixel_Buds',
#  '/wiki/Infobox',
#  '/wiki/Google_Environment',
#  '/wiki/Android_software_development',
#  '/wiki/Discovery_system_(AI_research)',
#  '/wiki/Pixel_2',
#  '/wiki/Google_Developers_Live',
#  '/wiki/Google_Student_Ambassador_Program',
#  '/wiki/The_Creepy_Line',
#  '/wiki/List_of_Fitbit_products',
#  '/wiki/Amit_Singhal',
#  '/wiki/History_of_Gmail',
#  '/wiki/Nexus_S',
#  '/wiki/Google_Swiffy',
#  '/wiki/Viv_(software)',
#  '/wiki/Google_Books',
#  '/wiki/Google_barges',
#  '/wiki/Project_Nightingale',
#  '/wiki/Google_Wave_Federation_Protocol',
#  '/wiki/Project_Sunroof',
#  '/wiki/Google_Scholar',
#  '/wiki/Google_Spaces',
#  '/wiki/OpenRefine',
#  '/wiki/Softcard',
#  '/wiki/ElgooG',
#  '/wiki/Google_Search',
#  '/wiki/Noto_fonts',
#  '/wiki/Google_Cloud_Datastore',
#  '/wiki/Google_Japanese_Input',
#  '/wiki/Material_Design',
#  '/wiki/Google_Health',
#  '/wiki/Google_Forms',
#  '/wiki/Predictions_of_the_end_of_Google',
#  '/wiki/Google_Moderator',
#  '/wiki/Google_One',
#  '/wiki/Alphabet_Workers_Union',
#  '/wiki/Vint_Cerf',
#  '/wiki/Authority_control',
#  '/wiki/David_Drummond_(businessman)',
#  '/wiki/Google_Lunar_X_Prize',
#  '/wiki/Sitelink',
#  '/wiki/OKR',
#  '/wiki/Google_Cloud_Connect',
#  '/wiki/Google_Dictionary',
#  '/wiki/Italian_language',
#  '/wiki/VP9',
#  '/wiki/Google_Contributor',
#  '/wiki/Fast_Pair',
#  '/wiki/Sidewalk_Toronto',
#  '/wiki/Privacy_concerns_regarding_Google',
#  '/wiki/Google%27s_Ideological_Echo_Chamber',
#  '/wiki/WDYL_(search_engine)',
#  '/wiki/Google_Home',
#  '/wiki/ITA_Software',
#  '/wiki/SageTV',
#  '/wiki/Go_(programming_language)',
#  '/wiki/Google_Current',
#  '/wiki/Sundar_Pichai',
#  '/wiki/Google_Code_Search',
#  '/wiki/Google_Schemer',
#  '/wiki/Google_Arts_%26_Culture',
#  '/wiki/Google_Play_Services',
#  '/wiki/Google_Me_(film)',
#  '/wiki/Google_litigation',
#  '/wiki/FeedBurner',
#  '/wiki/Pixel_Slate',
#  '/wiki/Madonna_(entertainer)',
#  '/wiki/Chelsea_Market',
#  '/wiki/Google_Primer',
#  '/wiki/Android_Developer_Lab',
#  '/wiki/Google_Travel',
#  '/wiki/Like.com',
#  '/wiki/Google_OnHub',
#  '/wiki/David_Cheriton',
#  '/wiki/Alan_Eustace',
#  '/wiki/Looker_(company)',
#  '/wiki/Caja_project',
#  '/wiki/Spanish_language',
#  '/wiki/Google_Chat',
#  '/wiki/Sparrow_(email_client)',
#  '/wiki/Google_Allo',
#  '/wiki/Google_Chrome_App',
#  '/wiki/Google_Fonts',
#  '/wiki/Andy_Bechtolsheim',
#  '/wiki/Polymer_(library)',
#  '/wiki/Rajen_Sheth',
#  '/wiki/Google_Santa_Tracker',
#  '/wiki/BebaPay',
#  '/wiki/Semantic_reasoner',
#  '/wiki/Nexus_10',
#  '/wiki/Nexus_7_(2013)',
#  '/wiki/Logic_programming',
#  '/wiki/Google_Chrome',
#  '/wiki/Kaltix',
#  '/wiki/Google_Trends',
#  '/wiki/Google_Nest',
#  '/wiki/New_Scientist',
#  '/wiki/Googlization',
#  '/wiki/IBM/Google_Cloud_Computing_University_Initiative',
#  '/wiki/Google_TalkBack',
#  '/wiki/Wikidata',
#  '/wiki/Google_Digital_Garage',
#  '/wiki/Fantastic_Adventures_scandal',
#  '/wiki/Google_Clips',
#  '/wiki/Begriffsschrift',
#  '/wiki/Central_Saint_Giles',
#  '/wiki/Google_Founders%27_Award',
#  '/wiki/Orbitera',
#  '/wiki/Google_Translator_Toolkit',
#  '/wiki/CNET',
#  '/wiki/St._John%27s_Terminal',
#  '/wiki/Hilbert%27s_program',
#  '/wiki/Google_worker_organization',
#  '/wiki/Dragonfly_(search_engine)',
#  '/wiki/Google_Flu_Trends',
#  '/wiki/Pixel_6',
#  '/wiki/Android_recovery_mode',
#  '/wiki/Pixelbook_Go',
#  '/wiki/World_Brain',
#  '/wiki/Reactions_to_Innocence_of_Muslims',
#  '/wiki/Knowledge_representation_and_reasoning',
#  '/wiki/Ann_Mather',
#  '/wiki/Bigtable',
#  '/wiki/WebRTC',
#  '/wiki/Web_Open_Font_Format',
#  '/wiki/BandPage',
#  '/wiki/Pixel_5a',
#  '/wiki/ALTS',
#  '/wiki/Android_App_Bundle',
#  '/wiki/Google_Mapathon',
#  '/wiki/Google_Public_DNS',
#  '/wiki/Blockly',
#  '/wiki/Google_Assistant',
#  '/wiki/Google_effect',
#  '/wiki/Songza',
#  '/wiki/Google_Squared',
#  '/wiki/.google',
#  '/wiki/Tractatus_Logico-Philosophicus',
#  '/wiki/G.co',
#  '/wiki/Google_Modular_Data_Center',
#  '/wiki/Google_Cloud_Dataflow',
#  '/wiki/Google_Hummingbird',
#  '/wiki/The_Baroque_Cycle',
#  '/wiki/Apk_(file_format)',
#  '/wiki/BufferBox',
#  '/wiki/Nexus_5',
#  '/wiki/DBpedia',
#  '/wiki/Android_(operating_system)',
#  '/wiki/2011_Slovenian_YouTube_incident',
#  '/wiki/Nexus_7_(2012)',
#  '/wiki/Chrome_Zone',
#  '/wiki/Google_Street_View_privacy_concerns',
#  '/wiki/VP3',
#  '/wiki/Tenor_(website)',
#  '/wiki/Google_Docs',
#  '/wiki/Tez_(software)',
#  '/wiki/Google_Family_Link',
#  '/wiki/YouTube_Poop',
#  '/wiki/Logical_atomism',
#  '/wiki/Google_Web_Accelerator',
#  '/wiki/Calculus_ratiocinator',
#  '/wiki/Google_Feud',
#  '/wiki/Talks_at_Google',
#  '/wiki/Google_Base',
#  '/wiki/YouTube_Next_Lab_and_Audience_Development_Group',
#  '/wiki/Knowledge_base',
#  '/wiki/Google_transliteration',
#  '/wiki/Google_Lively',
#  '/wiki/Search_Engine_Land',
#  '/wiki/Google_mobile_services',
#  '/wiki/MyTracks',
#  '/wiki/Typhoon_Studios',
#  '/wiki/Google_Play_Games',
#  '/wiki/Linked_data',
#  '/wiki/Chromebook',
#  '/wiki/Sawzall_(programming_language)',
#  '/wiki/Android_Automotive',
#  '/wiki/Google_Voice',
#  '/wiki/Nexus_Player',
#  '/wiki/Gizmo5',
#  '/wiki/Jeff_Dean',
#  '/wiki/GreenBorder',
#  '/wiki/German_language',
#  '/wiki/Orkut',
#  '/wiki/YouTube_Kids',
#  '/wiki/Wavii',
#  '/wiki/Bazel_(software)',
#  '/wiki/RightsFlow',
#  '/wiki/Knowledge-based_systems',
#  '/wiki/YouTuber_back_advertisement_controversy_in_Korea_in_2020',
#  '/wiki/Google_Play_Pass',
#  '/wiki/Japanese_language',
#  '/wiki/Dialogflow',
#  '/wiki/Google_Workspace',
#  '/wiki/Google_Developer_Expert',
#  '/wiki/Dariusz_Jemielniak',
#  '/wiki/Oath_Inc.',
#  '/wiki/Al_Gore',
#  '/wiki/Google_Surveys',
#  '/wiki/VP8',
#  '/wiki/Google_Hacks',
#  '/wiki/App_Inventor_for_Android',
#  '/wiki/Sanjay_Ghemawat',
#  '/wiki/Tango_(platform)',
#  '/wiki/Google_Podcasts',
#  '/wiki/2018_Google_walkouts',
#  '/wiki/Reqwireless',
#  '/wiki/Knol',
#  '/wiki/Galaxy_Nexus',
#  '/wiki/Oyster_(company)',
#  '/wiki/Gmail_interface',
#  '/wiki/Cyc',
#  '/wiki/Alan_Mulally',
#  '/wiki/Jaiku',
#  '/wiki/Google_for_Education',
#  '/wiki/Bengali_language',
#  '/wiki/Portuguese_language',
#  '/wiki/Bump_(application)',
#  '/wiki/Google_Station',
#  '/wiki/SlickLogin',
#  '/wiki/Keyhole_Markup_Language',
#  '/wiki/Google_Fi',
#  '/wiki/Google_Map_Maker',
#  '/wiki/Siri',
#  '/wiki/Timnit_Gebru',
#  '/wiki/Google_Code_Jam',
#  '/wiki/A.I._Artificial_Intelligence',
#  '/wiki/Androidland',
#  '/wiki/Android_TV',
#  '/wiki/Aardvark_(search_engine)',
#  '/wiki/List_of_fictional_computers',
#  '/wiki/Google_Opinion_Rewards',
#  '/wiki/Skia_Graphics_Engine',
#  '/wiki/Google_Nest_(smart_speakers)',
#  '/wiki/Pixelbook',
#  '/wiki/Chromebit',
#  '/wiki/Goobuntu',
#  '/wiki/In_the_Plex',
#  '/wiki/Semantic_network',
#  '/wiki/Characteristica_universalis',
#  '/wiki/Zairja',
#  '/wiki/Endoxon',
#  '/wiki/Google_Closure_Tools',
#  '/wiki/Google_Behind_the_Screen',
#  '/wiki/Gridcentric,_Inc.',
#  '/wiki/Google_Earth',
#  '/wiki/VisBug',
#  '/wiki/Google_Apps_Script',
#  '/wiki/Google_Insights_for_Search',
#  '/wiki/Mandiant',
#  '/wiki/Google_Contact_Lens',
#  '/wiki/Freebase_(database)',
#  '/wiki/Google_logo',
#  '/wiki/Google_Neural_Machine_Translation',
#  '/wiki/Google_tax',
#  '/wiki/List_of_apps_with_Google_Cast_support',
#  '/wiki/A_Google_A_Day',
#  '/wiki/Google_Finance',
#  '/wiki/Google_Lens',
#  '/wiki/YouTube_Music_Awards',
#  '/wiki/Google_China',
#  '/wiki/Android_Cloud_to_Device_Messaging',
#  '/wiki/Google_Translate',
#  '/wiki/San_Francisco_tech_bus_protests',
#  '/wiki/Google_Web_Server',
#  '/wiki/Google_Cloud_Platform',
#  '/wiki/Google_for_Startups',
#  '/wiki/GVisor',
#  '/wiki/Libvpx',
#  '/wiki/Marratech',
#  '/wiki/111_Eighth_Avenue',
#  '/wiki/ML_Fairness',
#  '/wiki/Larry_Page',
#  '/wiki/Android_Dev_Phone',
#  '/wiki/Tables_(Google)',
#  '/wiki/List_of_mergers_and_acquisitions_by_Alphabet',
#  '/wiki/Sensorvault',
#  '/wiki/Google_Charts',
#  '/wiki/Nearby_Share',
#  '/wiki/Meebo',
#  '/wiki/Google_Play_Books',
#  '/wiki/Firebase',
#  '/wiki/Pixel_(1st_generation)',
#  '/wiki/Google_One_Pass',
#  '/wiki/Google_News_%26_Weather',
#  '/wiki/Picnik',
#  '/wiki/Google_Sync',
#  '/wiki/Google_App_Engine',
#  '/wiki/Google_Maps_Navigation',
#  '/wiki/Wildfire_Interactive',
#  '/wiki/Digital_News_Initiative',
#  '/wiki/Alphabet_Inc.',
#  '/wiki/List_of_Google_Easter_eggs',
#  '/wiki/Google_Public_Data_Explorer',
#  '/wiki/Google_Toolbar',
#  '/wiki/Pixel_4a',
#  '/wiki/CNN/YouTube_presidential_debates',
#  '/wiki/Mayfield_Mall',
#  '/wiki/Knowledge_retrieval',
#  '/wiki/Dropcam',
#  '/wiki/Google_Doodle',
#  '/wiki/Chromebook_Pixel',
#  '/wiki/Versus_Debates',
#  '/wiki/Citation',
#  '/wiki/DoubleClick',
#  '/wiki/Google_Person_Finder',
#  '/wiki/Google_App_Runtime_for_Chrome',
#  '/wiki/Jigsaw_(company)',
#  '/wiki/Project_Shield',
#  '/wiki/Android_Auto',
#  '/wiki/Google_Quick_Search_Box',
#  '/wiki/The_Google_Book',
#  '/wiki/Google_SearchWiki',
#  '/wiki/Nexus_One',
#  '/wiki/French_language',
#  '/wiki/Google_Lighthouse',
#  '/wiki/Open_Location_Code',
#  '/wiki/History_of_Google',
#  '/wiki/Protocol_Buffers',
#  '/wiki/Guetzli',
#  '/wiki/Google_Pay',
#  '/wiki/Alphabet_of_human_thought',
#  '/wiki/Goojje',
#  '/wiki/YouTube_Symphony_Orchestra',
#  '/wiki/Google_News_Lab',
#  '/wiki/Tesseract_(software)',
#  '/wiki/Google_Domains',
#  '/wiki/Google_Patents',
#  '/wiki/Google_Shopping',
#  '/wiki/Dunant_(submarine_communications_cable)',
#  '/wiki/Live_Transcribe',
#  '/wiki/Google_Goggles',
#  '/wiki/Google_Guava',
#  '/wiki/Owlchemy_Labs',
#  '/wiki/Google_Slides',
#  '/wiki/YouTube_Theater',
#  '/wiki/Google_News_Archive',
#  '/wiki/Pixel_3a',
#  '/wiki/Sergey_Brin',
#  '/wiki/Google_Developers',
#  '/wiki/TensorFlow',
#  '/wiki/Google_Safe_Browsing',
#  '/wiki/Google_Cloud_Search',
#  '/wiki/Quantum_Artificial_Intelligence_Lab',
#  '/wiki/Censorship_by_Google#YouTube',
#  '/wiki/Poly_(website)',
#  '/wiki/YouTube_Comedy_Week',
#  '/wiki/Google_TV_(operating_system)',
#  '/wiki/Salar_Kamangar',
#  '/wiki/Google_Wave',
#  '/wiki/List_of_Stadia_games',
#  '/wiki/Google_Account',
#  '/wiki/Read_Along',
#  '/wiki/Google_hacking',
#  '/wiki/General_Problem_Solver',
#  '/wiki/Google_Optimize',
#  '/wiki/Google_Me_(song)',
#  '/wiki/YouTube_TV',
#  '/wiki/Wikimedia_Foundation',
#  '/wiki/Glass_OS',
#  '/wiki/Google_Gadgets',
#  '/wiki/Google_Photos',
#  '/wiki/Google_Glass',
#  '/wiki/Find_My_Device',
#  '/wiki/Croscore_fonts',
#  '/wiki/Google_Kythe',
#  '/wiki/OR-Tools',
#  '/wiki/Google_Pack',
#  '/wiki/Google_Notebook',
#  '/wiki/Google',
#  '/wiki/Google_Plugin_for_Eclipse',
#  '/wiki/Android_Developer_Challenge',
#  '/wiki/Dinosaur_Game',
#  '/wiki/ReCAPTCHA',
#  '/wiki/Google_Cast',
#  '/wiki/Hal_Varian',
#  '/wiki/Google_AI',
#  '/wiki/Google_Alerts',
#  '/wiki/Google_File_System',
#  '/wiki/History_of_YouTube',
#  '/wiki/Word_Lens',
#  '/wiki/Google_AdSense',
#  '/wiki/WaveNet',
#  '/wiki/Sitemaps',
#  '/wiki/Google_Offers',
#  '/wiki/Knowledge_graph',
#  '/wiki/Google_Pinyin',
#  '/wiki/Russian_language',
#  '/wiki/Neverware',
#  '/wiki/Google_Reader',
#  '/wiki/Google_Panda',
#  '/wiki/Apigee',
#  '/wiki/John_L._Hennessy',
#  '/wiki/FameBit',
#  '/wiki/Ray_Kurzweil',
#  '/wiki/2020_Google_services_outages',
#  '/wiki/Gerrit_(software)',
#  '/wiki/Project_Starline',
#  '/wiki/Google_PageSpeed_Tools',
#  '/wiki/Nexus_9',
#  '/wiki/Google_(verb)',
#  '/wiki/YouTube_copyright_strike',
#  '/wiki/Google_Voice_Search',
#  '/wiki/YouTube_Rewind',
#  '/wiki/Google_Shell',
#  '/wiki/List_of_Google_April_Fools%27_Day_jokes',
#  '/wiki/Google_Maps',
#  '/wiki/Google_Pixel',
#  '/wiki/Google_Native_Client',
#  '/wiki/Prolog',
#  '/wiki/FlatBuffers',
#  '/wiki/Postini',
#  '/wiki/Comparison_of_Google_Nexus_smartphones',
#  '/wiki/Fflick',
#  '/wiki/Google_Groups',
#  '/wiki/The_World_Factbook',
#  '/wiki/YouTube_Space_Lab',
#  '/wiki/OpenSocial',
#  '/wiki/Google_Science_Fair',
#  '/wiki/Google_Dashboard',
#  '/wiki/Inference_engine',
#  '/wiki/Flutter_(software)',
#  '/wiki/Flutter_(American_company)',
#  '/wiki/List_of_Google_Play_edition_devices',
#  '/wiki/Metaweb',
#  '/wiki/Google_Nexus',
#  '/wiki/Wikipedia',
#  '/wiki/Kubernetes',
#  '/wiki/Google_Data_Protocol',
#  '/wiki/Site_reliability_engineering',
#  '/wiki/Google_IME',
#  '/wiki/Project_Ara',
#  '/wiki/Internet_Low_Bitrate_Codec',
#  '/wiki/Google_Building_Maker',
#  '/wiki/Google_Gesture_Search',
#  '/wiki/Google_Cloud_Storage',
#  '/wiki/Omid_Kordestani',
#  '/wiki/Thomas_Jefferson',
#  '/wiki/Comparison_of_Google_Nexus_tablets',
#  '/wiki/Pimp_My_Search',
#  '/wiki/Datacommons.org',
#  '/wiki/Quickoffice',
#  '/wiki/Google_PowerMeter',
#  '/wiki/Neatx',
#  '/wiki/Google_and_the_World_Brain',
#  '/wiki/Gboard',
#  '/wiki/Pixel_C',
#  '/wiki/Stanford_Digital_Library_Project',
#  '/wiki/GRPC',
#  '/wiki/Google_Daydream',
#  '/wiki/Liquid_Galaxy',
#  '/wiki/Google_Workspace_Marketplace',
#  '/wiki/The_Engine',
#  '/wiki/Magic_Cat_Academy',
#  '/wiki/BumpTop',
#  '/wiki/Doodle4Google',
#  '/wiki/Google_Public_Alerts',
#  '/wiki/Made_with_Code',
#  '/wiki/CBS_Interactive']

# %%
def get_wiki_links(partial_url, nodes_neighbors, search_depth):
    """
    Collects links from the given Wikipedia page, stores them as a list of outgoing edges for this page's node.
    TODO Recursively calls itself on each page found, decrementing search depth each round until depth is zero.
    
    Parameters:
    -----------
    partial_url (str) : string of the form /wiki/Name_of_article for the target article
    search_depth (int) : number of search rounds remaining in recursion
    nodes_neighbors (dict) : existing dictionary of {page: [list, of, pages, linked]) to which we add
    
    Returns:
    --------
    nodes_neighbors (dict) : dict including edges for this page, used for directed graph in neo4j
    
    """
    # get data from specified wiki page and use bs4 to parse it
    page = requests.get(f'https://en.wikipedia.org{partial_url}')
    soup = BeautifulSoup(page.content, 'html.parser')
    # get main body text content from nested mw-content-text div
    body = soup.find("div", {"id": "bodyContent"}).find("div", {"id": "mw-content-text"})
    # get all a tags and extract link from each
    fa = body.find_all('a', href=True)
    links = [a['href'] for a in fa]
    # filter out the links that don't go to other wiki pages, match regex for wiki endpoint 
    labels_all = list(filter(re.compile("^/wiki/").match, links))
    # exclude files, specials, templates, etc. subtracts strings of format Type:resource
    labels = list(set(labels_all) - set(filter(re.compile(".*:.*").match, labels_all)))
    # add labels to dict entry for this node
    nodes_neighbors[partial_url] = labels

    return nodes_neighbors

# %%
gkg_dict = get_wiki_links('/wiki/Agalychnis_callidryas', dict(), 1)
gkg_dict
# Out:
# {'/wiki/Agalychnis_callidryas': ['/wiki/ISSN_(identifier)',
#   '/wiki/CITES',
#   '/wiki/IUCN_Red_List',
#   '/wiki/Agalychnis',
#   '/wiki/S2CID_(identifier)',
#   '/wiki/Carrion',
#   '/wiki/Cercyonis',
#   '/wiki/Colombia',
#   '/wiki/Edward_Drinker_Cope',
#   '/wiki/Tadpole',
#   '/wiki/Carnivore',
#   '/wiki/Metamorphosis',
#   '/wiki/Bromelia',
#   '/wiki/Arboreal',
#   '/wiki/Ranoidea_chloris',
#   '/wiki/Least_Concern',
#   '/wiki/IUCN',
#   '/wiki/Doi_(identifier)',
#   '/wiki/Scale_(map)',
#   '/wiki/Wikispecies',
#   '/wiki/Phyllomedusinae',
#   '/wiki/Rainforest',
#   '/wiki/Binomial_nomenclature',
#   '/wiki/INaturalist',
#   '/wiki/Mexico',
#   '/wiki/ISBN_(identifier)',
#   '/wiki/Defensive_adaptation',
#   '/wiki/Barcode_of_Life_Data_System',
#   '/wiki/Central_America',
#   '/wiki/Camouflage',
#   '/wiki/Amplexus',
#   '/wiki/Wikidata',
#   '/wiki/Amphibian_Species_of_the_World',
#   '/wiki/Deimatic_behaviour',
#   '/wiki/Phenotypic_plasticity',
#   '/wiki/Phyllomedusidae',
#   '/wiki/Epiphyte',
#   '/wiki/Animal',
#   '/wiki/Chordate',
#   '/wiki/National_Center_for_Biotechnology_Information',
#   '/wiki/Animal_Diversity_Web',
#   '/wiki/Integrated_Taxonomic_Information_System',
#   '/wiki/Neotropical',
#   '/wiki/PMID_(identifier)',
#   '/wiki/PMC_(identifier)',
#   '/wiki/Hylidae',
#   '/wiki/Nocturnality',
#   '/wiki/Taxonomy_(biology)',
#   '/wiki/Tree',
#   '/wiki/AmphibiaWeb',
#   '/wiki/Copeia',
#   '/wiki/Greek_language',
#   '/wiki/Poisonous_amphibian',
#   '/wiki/Synonym_(taxonomy)',
#   '/wiki/Scientific_name',
#   '/wiki/Global_Biodiversity_Information_Facility',
#   '/wiki/Interim_Register_of_Marine_and_Nonmarine_Genera',
#   '/wiki/Clutch_(eggs)',
#   '/wiki/JSTOR_(identifier)',
#   '/wiki/Amphibian',
#   '/wiki/Frog',
#   '/wiki/Nictitating_membrane',
#   '/wiki/Conservation_status',
#   '/wiki/Encyclopedia_of_Life']}

# %% [markdown]
# ## Generating a graph

# %%
# loop over valid wiki page links and call some function on them that collects information IFF they aren't already in the list of added 

# make the above into a function, pass a /wiki/Page_name_from_url and a number of search depth remaining
# that gets decremented for each recursive call

# %% [markdown]
# TODO: shape our data so that we can have a json dict of nodes and edges that is interpretable by neo4j!
